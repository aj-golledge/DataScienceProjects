# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Generate some sample data (replace this with your own data)
data = np.random.normal(loc=0, scale=1, size=1000)

# Create a KDE plot (smooth curve)
sns.kdeplot(data, shade=True)

# Add labels and a title
plt.xlabel('X-axis')
plt.ylabel('Density')
plt.title('Smooth Curve (KDE) Plot')

# Show the plot
plt.show()
# Out:
# /var/folders/6c/psx92cbd57gd1gk2h4klzk_w0000gn/T/ipykernel_1110/2981535041.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data, shade=True)
